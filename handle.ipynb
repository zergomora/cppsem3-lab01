# %%
import pandas as pd 

df = pd.read_csv("second.csv", delimiter='\t')

df
# Out:
#     Target  Standart     Three   Penalty     Bonus
# 0        1  0.010020  0.000000  0.019945  0.000089
# 1        2  0.009850  0.000000  0.019566  0.000297
# 2        3  0.009961  0.004586  0.019363  0.000509
# 3        4  0.009910  0.014114  0.019253  0.000707
# 4        5  0.009884  0.027846  0.019234  0.000887
# ..     ...       ...       ...       ...       ...
# 94      95  0.010035  0.000000  0.001093  0.018838
# 95      96  0.010169  0.000000  0.000890  0.019476
# 96      97  0.009928  0.000000  0.000709  0.019054
# 97      98  0.010149  0.000000  0.000503  0.019515
# 98      99  0.010162  0.000000  0.000277  0.019692
#
# [99 rows x 5 columns]

# %%
import matplotlib.pyplot as plt 

plt.bar(df["Target"], df["Standart"])

plt.title('Standart Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.show()

# %%
plt.bar(df["Target"], df["Three"])

plt.title('Three Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([2,19])
plt.show()

# %%
plt.bar(df["Target"], df["Penalty"], label="Penalty")
plt.bar(df["Target"], df["Bonus"], label="Bonus")

plt.title('Penalty&Bonus Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.legend()
plt.show()

# %%
df = pd.read_csv("third.csv", delimiter='\t')

plt.bar(df["Target"], df["Double"])

plt.title('Double Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.show()
