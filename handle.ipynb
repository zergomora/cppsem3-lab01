# %%
import pandas as pd 

df = pd.read_csv("second.csv", delimiter='\t')

df
# Out:
#     Target  Standart    Three  Penalty    Bonus
# 0        1   0.01042  0.16779  0.01011  0.00970
# 1        2   0.00973  0.16444  0.01040  0.00958
# 2        3   0.01041  0.16639  0.01030  0.01040
# 3        4   0.00976  0.16666  0.00990  0.01015
# 4        5   0.01042  0.16561  0.01025  0.01064
# ..     ...       ...      ...      ...      ...
# 94      95   0.01042  0.00000  0.01043  0.00967
# 95      96   0.01042  0.00000  0.00990  0.00983
# 96      97   0.01005  0.00000  0.01008  0.00992
# 97      98   0.01008  0.00000  0.00984  0.01020
# 98      99   0.01005  0.00000  0.00976  0.01021
#
# [99 rows x 5 columns]

# %%
import matplotlib.pyplot as plt 

plt.bar(df["Target"], df["Standart"])

plt.title('Standart Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.show()

# %%
plt.bar(df["Target"], df["Three"])

plt.title('Three Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([0,7])
plt.show()

# %%
plt.bar(df["Target"], df["Penalty"], label="Penalty")
plt.bar(df["Target"], df["Bonus"], label="Bonus")

plt.title('Penalty&Bonus Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.legend()
plt.show()

# %%
df = pd.read_csv("third.csv", delimiter='\t')

plt.bar(df["Target"], df["Double"])

plt.title('Double Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.show()
