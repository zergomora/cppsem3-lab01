# %%
import pandas as pd 

df = pd.read_csv("second.csv", delimiter='\t')

df
# Out:
#     Target  Standart    Three  Penalty    Bonus
# 0        1   0.00983  0.00000  0.01973  0.00013
# 1        2   0.01016  0.00000  0.01991  0.00031
# 2        3   0.00928  0.00000  0.02024  0.00064
# 3        4   0.01013  0.00000  0.01872  0.00067
# 4        5   0.00996  0.00000  0.01863  0.00098
# ..     ...       ...      ...      ...      ...
# 94      95   0.00964  0.00469  0.00101  0.01899
# 95      96   0.00990  0.00445  0.00076  0.01883
# 96      97   0.00983  0.00470  0.00073  0.01984
# 97      98   0.00984  0.00468  0.00037  0.01905
# 98      99   0.00954  0.00469  0.00033  0.02016
#
# [99 rows x 5 columns]

# %%
import matplotlib.pyplot as plt 

plt.bar(df["Target"], df["Standart"])

plt.title('Standart Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.show()

# %%
plt.bar(df["Target"], df["Three"])

plt.title('Three Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([0,20])
plt.show()

# %%
plt.bar(df["Target"], df["Penalty"], label="Penalty")
plt.bar(df["Target"], df["Bonus"], label="Bonus")

plt.title('Penalty&Bonus Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.legend()
plt.show()

# %%
df = pd.read_csv("third.csv", delimiter='\t')

plt.bar(df["Target"], df["Double"])

plt.title('Double Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.show()
