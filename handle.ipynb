# %%
import pandas as pd 

df = pd.read_csv("second.csv", delimiter='\t')

df
# Out:
#     Target  Standart    Three  Penalty    Bonus
# 0        1   0.00970  0.00000  0.01982  0.00012
# 1        2   0.00968  0.00000  0.02050  0.00033
# 2        3   0.01087  0.00451  0.01934  0.00040
# 3        4   0.00939  0.01358  0.02027  0.00069
# 4        5   0.01018  0.02752  0.01863  0.00098
# ..     ...       ...      ...      ...      ...
# 94      95   0.01010  0.00000  0.00103  0.01884
# 95      96   0.01022  0.00000  0.00095  0.01999
# 96      97   0.00990  0.00000  0.00064  0.01926
# 97      98   0.01009  0.00000  0.00058  0.01917
# 98      99   0.01014  0.00000  0.00028  0.01933
#
# [99 rows x 5 columns]

# %%
import matplotlib.pyplot as plt 

plt.bar(df["Target"], df["Standart"])

plt.title('Standart Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.show()

# %%
plt.bar(df["Target"], df["Three"])

plt.title('Three Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([2,19])
plt.show()

# %%
plt.bar(df["Target"], df["Penalty"], label="Penalty")
plt.bar(df["Target"], df["Bonus"], label="Bonus")

plt.title('Penalty&Bonus Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.legend()
plt.show()

# %%
df = pd.read_csv("third.csv", delimiter='\t')

plt.bar(df["Target"], df["Double"])

plt.title('Double Dice')
plt.ylabel(r'Вероятность попадания $\omega$')
plt.xlabel('Значение X')

plt.xlim([1,100])
plt.show()
